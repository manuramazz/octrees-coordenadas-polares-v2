# %%
from utils import *
from plots import *
from constants import *
from pathlib import Path
import os


# %load_ext autoreload
# %autoreload 2

RANGES_PATH = os.path.join("..", "out_tfg_ranges")
# Out:
# Failed to read module file '\\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\plots_manu\plots.py' for module 'plots': UnicodeDecodeError
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Roaming\Python\Python313\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 556, in maybe_reload_module
#     new_source_code = f.read()
#   File "c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 1274: character maps to <undefined>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\plots_manu\plots.py:840: SyntaxWarning: invalid escape sequence '\ '
#   tex_kernel = kernel_titles.get(kern.lower(), f'{kern.upper()}')

# %%
for log in Path(RANGES_PATH).glob('*.log'):
        plot_pruning_points(log, save=False)
# Out:
# Failed to read module file '\\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\plots_manu\plots.py' for module 'plots': UnicodeDecodeError
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Roaming\Python\Python313\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 556, in maybe_reload_module
#     new_source_code = f.read()
#   File "c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 1274: character maps to <undefined>
# \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\plots_manu\plots.py:841: SyntaxWarning: invalid escape sequence '\ '
#   ax.set_title(f'{tex_kernel}\n' r'$r = ' f'{rad}\ m$', fontsize=15, pad=10)
# Generando gráfico para Dataset PNOA_2024_PNR_489 Modo: cartesian | Config: threshold=16 | maxPointsLeaf=128
# Generando gráfico para Dataset PNOA_2024_PNR_489 Modo: polar | Config: threshold=16 | maxPointsLeaf=128
# Generando gráfico para Dataset Paris_Luxembourg_6 Modo: cartesian | Config: threshold=16 | maxPointsLeaf=128
# Generando gráfico para Dataset Paris_Luxembourg_6 Modo: polar | Config: threshold=16 | maxPointsLeaf=128
# Generando gráfico para Dataset Lille_0 Modo: cartesian | Config: threshold=16 | maxPointsLeaf=128
# Generando gráfico para Dataset Lille_0 Modo: polar | Config: threshold=16 | maxPointsLeaf=128
# Generando gráfico para Dataset 5085_54320 Modo: cartesian | Config: threshold=16 | maxPointsLeaf=128
# Generando gráfico para Dataset 5085_54320 Modo: polar | Config: threshold=16 | maxPointsLeaf=128
# Generando gráfico para Dataset Mar18_train Modo: cartesian | Config: threshold=16 | maxPointsLeaf=128
# Generando gráfico para Dataset Mar18_train Modo: polar | Config: threshold=16 | maxPointsLeaf=128
# Generando gráfico para Dataset 5095_54440 Modo: cartesian | Config: threshold=16 | maxPointsLeaf=128
# Generando gráfico para Dataset 5095_54440 Modo: polar | Config: threshold=16 | maxPointsLeaf=128
# Generando gráfico para Dataset sg27_station8_intensity_rgb Modo: cartesian | Config: threshold=16 | maxPointsLeaf=128
# Generando gráfico para Dataset sg27_station8_intensity_rgb Modo: polar | Config: threshold=16 | maxPointsLeaf=128
# Generando gráfico para Dataset bildstein_station1_xyz_intensity_rgb Modo: cartesian | Config: threshold=16 | maxPointsLeaf=128
# Generando gráfico para Dataset bildstein_station1_xyz_intensity_rgb Modo: polar | Config: threshold=16 | maxPointsLeaf=128
# Generando gráfico para Dataset Mar18_test Modo: cartesian | Config: threshold=16 | maxPointsLeaf=128
# Generando gráfico para Dataset Mar18_test Modo: polar | Config: threshold=16 | maxPointsLeaf=128

# %%
for log in Path(RANGES_PATH).glob('*.log'):
        plot_key_distribution(log)
