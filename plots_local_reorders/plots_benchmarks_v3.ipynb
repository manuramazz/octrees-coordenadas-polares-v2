# %% [markdown]
# ### BÚSQUEDAS ALEATORIAS (10K BÚSQUEDAS)
# Se realizan sobre neighborsPrune y neighborsStruct usando modos sin reordenación, polar y cartesiana.
# Para neighborsStruct solo es posible aplicar reordenación polar.

# %%
import os
import seaborn as sns
from utils import *
from plots import *
from constants import *
# %load_ext autoreload
# %autoreload 2
BASE_DATA_PATH = os.path.join("..", "out_tfg_reorders_v3")
SUBSET_DATA = os.path.join(BASE_DATA_PATH, "subset")
FULL_DATA = os.path.join(BASE_DATA_PATH, "full")
PARALLEL_SUBSET_DATA = os.path.join(BASE_DATA_PATH, "parallel_subset")
PARALLEL_FULL_DATA = os.path.join(BASE_DATA_PATH, "parallel_full")
OUTPUT_FOLDER = os.path.join("..", "out", "figures", "benchmarks")
PNOA = "PNOA_2024_PNR_489-4672_NPC01"

set_default_style()
# Out:
# Failed to read module file '\\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\plots_local_reorders\plots.py' for module 'plots': UnicodeDecodeError
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Roaming\Python\Python313\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 556, in maybe_reload_module
#     new_source_code = f.read()
#   File "c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 1274: character maps to <undefined>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ...

# %% [markdown]
# ### Figuras de tiempo de ejecución
# Para un radio dado, todas las combinaciones algoritmo + reordenamiento para distintos tamaños de hoja.

# %%
figs = plot_reorder_vs_base(SUBSET_DATA, "Paris_Luxembourg_6", allFiles=True, kernel="all", radius="all")
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\subset\Paris_Luxembourg_6
# ..\out_tfg_reorders_v3\subset\Paris_Luxembourg_6
# Loading results file: ..\out_tfg_reorders_v3\subset\Paris_Luxembourg_6\Paris_Luxembourg_6-2026-06-07-16_38_56.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Paris_Luxembourg_6\Paris_Luxembourg_6-2026-06-07-17_22_06.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Paris_Luxembourg_6\Paris_Luxembourg_6-2026-06-07-17_08_32.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Paris_Luxembourg_6\Paris_Luxembourg_6-2026-06-07-17_13_10.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Paris_Luxembourg_6\Paris_Luxembourg_6-2026-06-07-17_17_36.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Paris_Luxembourg_6\Paris_Luxembourg_6-2026-06-07-16_51_14.csv
# ...

# %%
figs = plot_reorder_vs_base(SUBSET_DATA, "5085_54320", allFiles=True, kernel="all", radius="all")
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\subset\5085_54320
# ..\out_tfg_reorders_v3\subset\5085_54320
# Loading results file: ..\out_tfg_reorders_v3\subset\5085_54320\5085_54320-2026-06-07-14_18_11.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5085_54320\5085_54320-2026-06-07-14_22_43.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5085_54320\5085_54320-2026-06-07-14_25_16.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5085_54320\5085_54320-2026-06-07-14_27_10.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5085_54320\5085_54320-2026-06-07-14_17_30.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5085_54320\5085_54320-2026-06-07-14_16_40.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5085_54320\5085_54320-2026-06-07-14_19_00.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5085_54320\5085_54320-2026-06-07-14_28_06.csv
# ...

# %%
figs = plot_reorder_vs_base(SUBSET_DATA, "5095_54440", allFiles=True, kernel="all", radius="all")
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\subset\5095_54440
# ..\out_tfg_reorders_v3\subset\5095_54440
# Loading results file: ..\out_tfg_reorders_v3\subset\5095_54440\5095_54440-2026-06-07-14_33_34.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5095_54440\5095_54440-2026-06-07-14_28_58.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5095_54440\5095_54440-2026-06-07-14_35_39.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5095_54440\5095_54440-2026-06-07-14_36_23.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5095_54440\5095_54440-2026-06-07-14_30_50.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5095_54440\5095_54440-2026-06-07-14_37_06.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5095_54440\5095_54440-2026-06-07-14_38_37.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5095_54440\5095_54440-2026-06-07-14_29_36.csv
# ...

# %%
fig = plot_reorder_vs_base(SUBSET_DATA, "bildstein_station1_xyz_intensity_rgb", allFiles=True, kernel="all", radius="all")
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\subset\bildstein_station1_xyz_intensity_rgb
# ..\out_tfg_reorders_v3\subset\bildstein_station1_xyz_intensity_rgb
# Loading results file: ..\out_tfg_reorders_v3\subset\bildstein_station1_xyz_intensity_rgb\bildstein_station1_xyz_intensity_rgb-2026-06-07-17_50_16.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\bildstein_station1_xyz_intensity_rgb\bildstein_station1_xyz_intensity_rgb-2026-06-07-17_51_40.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\bildstein_station1_xyz_intensity_rgb\bildstein_station1_xyz_intensity_rgb-2026-06-07-17_56_00.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\bildstein_station1_xyz_intensity_rgb\bildstein_station1_xyz_intensity_rgb-2026-06-07-17_53_04.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\bildstein_station1_xyz_intensity_rgb\bildstein_station1_xyz_intensity_rgb-2026-06-07-17_43_23.csv
# ...

# %%
figs = plot_reorder_vs_base(SUBSET_DATA, PNOA, allFiles=True, kernel="all", radius="all")
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\subset\PNOA_2024_PNR_489-4672_NPC01
# ..\out_tfg_reorders_v3\subset\PNOA_2024_PNR_489-4672_NPC01
# Loading results file: ..\out_tfg_reorders_v3\subset\PNOA_2024_PNR_489-4672_NPC01\PNOA_2024_PNR_489-4672_NPC01-2026-06-07-14_42_36.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\PNOA_2024_PNR_489-4672_NPC01\PNOA_2024_PNR_489-4672_NPC01-2026-06-07-14_48_52.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\PNOA_2024_PNR_489-4672_NPC01\PNOA_2024_PNR_489-4672_NPC01-2026-06-07-14_41_59.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\PNOA_2024_PNR_489-4672_NPC01\PNOA_2024_PNR_489-4672_NPC01-2026-06-07-14_47_22.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\PNOA_2024_PNR_489-4672_NPC01\PNOA_2024_PNR_489-4672_NPC01-2026-06-07-14_45_55.csv
# ...

# %%
figs = plot_reorder_vs_base(SUBSET_DATA, "Lille_0", allFiles=True, kernel="all", radius="all")
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\subset\Lille_0
# ..\out_tfg_reorders_v3\subset\Lille_0
# Loading results file: ..\out_tfg_reorders_v3\subset\Lille_0\Lille_0-2026-06-07-16_10_41.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Lille_0\Lille_0-2026-06-07-16_21_50.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Lille_0\Lille_0-2026-06-07-16_19_54.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Lille_0\Lille_0-2026-06-07-16_30_31.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Lille_0\Lille_0-2026-06-07-16_28_17.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Lille_0\Lille_0-2026-06-07-16_08_52.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Lille_0\Lille_0-2026-06-07-16_26_08.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Lille_0\Lille_0-2026-06-07-16_32_39.csv
# ...

# %%
fig = plot_reorder_vs_base(SUBSET_DATA, "sg27_station8_intensity_rgb", allFiles=True, kernel="all", radius="all")
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\subset\sg27_station8_intensity_rgb
# ..\out_tfg_reorders_v3\subset\sg27_station8_intensity_rgb
# Loading results file: ..\out_tfg_reorders_v3\subset\sg27_station8_intensity_rgb\sg27_station8_intensity_rgb-2026-06-07-18_38_53.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\sg27_station8_intensity_rgb\sg27_station8_intensity_rgb-2026-06-07-19_05_00.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\sg27_station8_intensity_rgb\sg27_station8_intensity_rgb-2026-06-07-18_17_09.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\sg27_station8_intensity_rgb\sg27_station8_intensity_rgb-2026-06-07-18_49_05.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\sg27_station8_intensity_rgb\sg27_station8_intensity_rgb-2026-06-07-18_07_08.csv
# ...

# %% [markdown]
# ## Heatmap de hiperparámetros para poda (tamaño hoja + threshold)
# Se utiliza una métrica de speedup relativo contra el mejor caso por radio + kernel. El valor mostrado es una media de todos esos speedups para cada valor de radio + kernel probado.
# El objetivo es tener una visión general de qué combinación es más efectiva.

# %%
figs = plot_threshold_heatmap_comparison(SUBSET_DATA, "Paris_Luxembourg_6", allFiles=True, kernel="all", radius="all")
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\subset\Paris_Luxembourg_6
# ..\out_tfg_reorders_v3\subset\Paris_Luxembourg_6
# Loading results file: ..\out_tfg_reorders_v3\subset\Paris_Luxembourg_6\Paris_Luxembourg_6-2026-06-07-16_38_56.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Paris_Luxembourg_6\Paris_Luxembourg_6-2026-06-07-17_22_06.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Paris_Luxembourg_6\Paris_Luxembourg_6-2026-06-07-17_08_32.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Paris_Luxembourg_6\Paris_Luxembourg_6-2026-06-07-17_13_10.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Paris_Luxembourg_6\Paris_Luxembourg_6-2026-06-07-17_17_36.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Paris_Luxembourg_6\Paris_Luxembourg_6-2026-06-07-16_51_14.csv
# ...

# %%
figsC = plot_threshold_heatmap_comparison(SUBSET_DATA, "Lille_0", allFiles=True, kernel="all", radius="all")
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\subset\Lille_0
# ..\out_tfg_reorders_v3\subset\Lille_0
# Loading results file: ..\out_tfg_reorders_v3\subset\Lille_0\Lille_0-2026-06-07-16_10_41.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Lille_0\Lille_0-2026-06-07-16_21_50.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Lille_0\Lille_0-2026-06-07-16_19_54.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Lille_0\Lille_0-2026-06-07-16_30_31.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Lille_0\Lille_0-2026-06-07-16_28_17.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Lille_0\Lille_0-2026-06-07-16_08_52.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Lille_0\Lille_0-2026-06-07-16_26_08.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Lille_0\Lille_0-2026-06-07-16_32_39.csv
# ...

# %%
figsC = plot_threshold_heatmap_comparison(SUBSET_DATA, PNOA, allFiles=True, kernel="all", radius="all")
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\subset\PNOA_2024_PNR_489-4672_NPC01
# ..\out_tfg_reorders_v3\subset\PNOA_2024_PNR_489-4672_NPC01
# Loading results file: ..\out_tfg_reorders_v3\subset\PNOA_2024_PNR_489-4672_NPC01\PNOA_2024_PNR_489-4672_NPC01-2026-06-07-14_42_36.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\PNOA_2024_PNR_489-4672_NPC01\PNOA_2024_PNR_489-4672_NPC01-2026-06-07-14_48_52.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\PNOA_2024_PNR_489-4672_NPC01\PNOA_2024_PNR_489-4672_NPC01-2026-06-07-14_41_59.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\PNOA_2024_PNR_489-4672_NPC01\PNOA_2024_PNR_489-4672_NPC01-2026-06-07-14_47_22.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\PNOA_2024_PNR_489-4672_NPC01\PNOA_2024_PNR_489-4672_NPC01-2026-06-07-14_45_55.csv
# ...

# %%
figsC = plot_threshold_heatmap_comparison(SUBSET_DATA, "bildstein_station1_xyz_intensity_rgb", allFiles=True, kernel="all", radius="all")
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\subset\bildstein_station1_xyz_intensity_rgb
# ..\out_tfg_reorders_v3\subset\bildstein_station1_xyz_intensity_rgb
# Loading results file: ..\out_tfg_reorders_v3\subset\bildstein_station1_xyz_intensity_rgb\bildstein_station1_xyz_intensity_rgb-2026-06-07-17_50_16.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\bildstein_station1_xyz_intensity_rgb\bildstein_station1_xyz_intensity_rgb-2026-06-07-17_51_40.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\bildstein_station1_xyz_intensity_rgb\bildstein_station1_xyz_intensity_rgb-2026-06-07-17_56_00.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\bildstein_station1_xyz_intensity_rgb\bildstein_station1_xyz_intensity_rgb-2026-06-07-17_53_04.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\bildstein_station1_xyz_intensity_rgb\bildstein_station1_xyz_intensity_rgb-2026-06-07-17_43_23.csv
# ...

# %%
figsC = plot_threshold_heatmap_comparison(SUBSET_DATA, "5085_54320", allFiles=True, kernel="all", radius="all")
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\subset\5085_54320
# ..\out_tfg_reorders_v3\subset\5085_54320
# Loading results file: ..\out_tfg_reorders_v3\subset\5085_54320\5085_54320-2026-06-07-14_18_11.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5085_54320\5085_54320-2026-06-07-14_22_43.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5085_54320\5085_54320-2026-06-07-14_25_16.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5085_54320\5085_54320-2026-06-07-14_27_10.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5085_54320\5085_54320-2026-06-07-14_17_30.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5085_54320\5085_54320-2026-06-07-14_16_40.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5085_54320\5085_54320-2026-06-07-14_19_00.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5085_54320\5085_54320-2026-06-07-14_28_06.csv
# ...

# %%
figsC = plot_threshold_heatmap_comparison(SUBSET_DATA, "5095_54440", allFiles=True, kernel="all", radius="all")
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\subset\5095_54440
# ..\out_tfg_reorders_v3\subset\5095_54440
# Loading results file: ..\out_tfg_reorders_v3\subset\5095_54440\5095_54440-2026-06-07-14_33_34.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5095_54440\5095_54440-2026-06-07-14_28_58.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5095_54440\5095_54440-2026-06-07-14_35_39.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5095_54440\5095_54440-2026-06-07-14_36_23.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5095_54440\5095_54440-2026-06-07-14_30_50.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5095_54440\5095_54440-2026-06-07-14_37_06.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5095_54440\5095_54440-2026-06-07-14_38_37.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5095_54440\5095_54440-2026-06-07-14_29_36.csv
# ...

# %%
figs = plot_threshold_heatmap_comparison(SUBSET_DATA, "Mar18_test", allFiles=True, kernel="all", radius="all")
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\subset\Mar18_test
# ..\out_tfg_reorders_v3\subset\Mar18_test
# Loading results file: ..\out_tfg_reorders_v3\subset\Mar18_test\Mar18_test-2026-06-07-15_29_47.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Mar18_test\Mar18_test-2026-06-07-15_58_47.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Mar18_test\Mar18_test-2026-06-07-15_27_11.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Mar18_test\Mar18_test-2026-06-07-16_01_58.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Mar18_test\Mar18_test-2026-06-07-15_46_06.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Mar18_test\Mar18_test-2026-06-07-15_52_17.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Mar18_test\Mar18_test-2026-06-07-15_49_08.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Mar18_test\Mar18_test-2026-06-07-15_24_38.csv
# ...

# %%
figs = plot_threshold_heatmap_comparison(SUBSET_DATA, "Mar18_train", allFiles=True, kernel="all", radius="all")
# Out:
# Failed to read module file '\\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\plots_manu\plots.py' for module 'plots': UnicodeDecodeError
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Roaming\Python\Python313\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 556, in maybe_reload_module
#     new_source_code = f.read()
#   File "c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 1296: character maps to <undefined>
# \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\plots_manu\plots.py:839: SyntaxWarning: invalid escape sequence '\ '
#   ax.set_title(f'{tex_kernel}\n' r'$r = ' f'{rad}\ m$', fontsize=15, pad=10)
# ...

# %%
figs = plot_threshold_heatmap_comparison(SUBSET_DATA, "sg27_station8_intensity_rgb", allFiles=True, kernel="all", radius="all")
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\subset\sg27_station8_intensity_rgb
# ..\out_tfg_reorders_v3\subset\sg27_station8_intensity_rgb
# Loading results file: ..\out_tfg_reorders_v3\subset\sg27_station8_intensity_rgb\sg27_station8_intensity_rgb-2026-06-07-18_38_53.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\sg27_station8_intensity_rgb\sg27_station8_intensity_rgb-2026-06-07-19_05_00.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\sg27_station8_intensity_rgb\sg27_station8_intensity_rgb-2026-06-07-18_17_09.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\sg27_station8_intensity_rgb\sg27_station8_intensity_rgb-2026-06-07-18_49_05.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\sg27_station8_intensity_rgb\sg27_station8_intensity_rgb-2026-06-07-18_07_08.csv
# ...

# %% [markdown]
# ### Tiempos de ejecución según el radio para cada nube
# Se cogen los valores de hiperparámetros para cada nube que fueron óptimos. En el caso de reordenaciones nulas se usan siempre tamaños de hoja de 128, en general es la que mejor funciona sin podar al ser la más pequeña, y es la que se usaba en los experimentos originales.

# %%
plot_scalability_lines(SUBSET_DATA, "Paris_Luxembourg_6", 128, 64)
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\subset\Paris_Luxembourg_6
# ..\out_tfg_reorders_v3\subset\Paris_Luxembourg_6
# Loading results file: ..\out_tfg_reorders_v3\subset\Paris_Luxembourg_6\Paris_Luxembourg_6-2026-06-07-16_38_56.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Paris_Luxembourg_6\Paris_Luxembourg_6-2026-06-07-17_22_06.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Paris_Luxembourg_6\Paris_Luxembourg_6-2026-06-07-17_08_32.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Paris_Luxembourg_6\Paris_Luxembourg_6-2026-06-07-17_13_10.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Paris_Luxembourg_6\Paris_Luxembourg_6-2026-06-07-17_17_36.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Paris_Luxembourg_6\Paris_Luxembourg_6-2026-06-07-16_51_14.csv
# ...

# %%
plot_scalability_lines(SUBSET_DATA, "Lille_0", 256, 64)
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\subset\Lille_0
# ..\out_tfg_reorders_v3\subset\Lille_0
# Loading results file: ..\out_tfg_reorders_v3\subset\Lille_0\Lille_0-2026-06-07-16_10_41.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Lille_0\Lille_0-2026-06-07-16_21_50.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Lille_0\Lille_0-2026-06-07-16_19_54.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Lille_0\Lille_0-2026-06-07-16_30_31.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Lille_0\Lille_0-2026-06-07-16_28_17.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Lille_0\Lille_0-2026-06-07-16_08_52.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Lille_0\Lille_0-2026-06-07-16_26_08.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Lille_0\Lille_0-2026-06-07-16_32_39.csv
# ...

# %%
plot_scalability_lines(SUBSET_DATA, "5085_54320", 512, 64)
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\subset\5085_54320
# ..\out_tfg_reorders_v3\subset\5085_54320
# Loading results file: ..\out_tfg_reorders_v3\subset\5085_54320\5085_54320-2026-06-07-14_18_11.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5085_54320\5085_54320-2026-06-07-14_22_43.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5085_54320\5085_54320-2026-06-07-14_25_16.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5085_54320\5085_54320-2026-06-07-14_27_10.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5085_54320\5085_54320-2026-06-07-14_17_30.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5085_54320\5085_54320-2026-06-07-14_16_40.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5085_54320\5085_54320-2026-06-07-14_19_00.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5085_54320\5085_54320-2026-06-07-14_28_06.csv
# ...

# %%
plot_scalability_lines(SUBSET_DATA, "5095_54440", 512, 64)
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\subset\5095_54440
# ..\out_tfg_reorders_v3\subset\5095_54440
# Loading results file: ..\out_tfg_reorders_v3\subset\5095_54440\5095_54440-2026-06-07-14_33_34.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5095_54440\5095_54440-2026-06-07-14_28_58.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5095_54440\5095_54440-2026-06-07-14_35_39.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5095_54440\5095_54440-2026-06-07-14_36_23.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5095_54440\5095_54440-2026-06-07-14_30_50.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5095_54440\5095_54440-2026-06-07-14_37_06.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5095_54440\5095_54440-2026-06-07-14_38_37.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\5095_54440\5095_54440-2026-06-07-14_29_36.csv
# ...

# %%
plot_scalability_lines(SUBSET_DATA, "bildstein_station1_xyz_intensity_rgb", 256, 64)
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\subset\bildstein_station1_xyz_intensity_rgb
# ..\out_tfg_reorders_v3\subset\bildstein_station1_xyz_intensity_rgb
# Loading results file: ..\out_tfg_reorders_v3\subset\bildstein_station1_xyz_intensity_rgb\bildstein_station1_xyz_intensity_rgb-2026-06-07-17_50_16.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\bildstein_station1_xyz_intensity_rgb\bildstein_station1_xyz_intensity_rgb-2026-06-07-17_51_40.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\bildstein_station1_xyz_intensity_rgb\bildstein_station1_xyz_intensity_rgb-2026-06-07-17_56_00.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\bildstein_station1_xyz_intensity_rgb\bildstein_station1_xyz_intensity_rgb-2026-06-07-17_53_04.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\bildstein_station1_xyz_intensity_rgb\bildstein_station1_xyz_intensity_rgb-2026-06-07-17_43_23.csv
# ...

# %%
plot_scalability_lines(SUBSET_DATA, "sg27_station8_intensity_rgb", 256, 64)
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\subset\sg27_station8_intensity_rgb
# ..\out_tfg_reorders_v3\subset\sg27_station8_intensity_rgb
# Loading results file: ..\out_tfg_reorders_v3\subset\sg27_station8_intensity_rgb\sg27_station8_intensity_rgb-2026-06-07-18_38_53.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\sg27_station8_intensity_rgb\sg27_station8_intensity_rgb-2026-06-07-19_05_00.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\sg27_station8_intensity_rgb\sg27_station8_intensity_rgb-2026-06-07-18_17_09.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\sg27_station8_intensity_rgb\sg27_station8_intensity_rgb-2026-06-07-18_49_05.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\sg27_station8_intensity_rgb\sg27_station8_intensity_rgb-2026-06-07-18_07_08.csv
# ...

# %%
plot_scalability_lines(SUBSET_DATA, "Mar18_train", 256, 16)
# Out:
# Failed to read module file '\\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\plots_manu\plots.py' for module 'plots': UnicodeDecodeError
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Roaming\Python\Python313\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 556, in maybe_reload_module
#     new_source_code = f.read()
#   File "c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 1296: character maps to <undefined>
# \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\plots_manu\plots.py:839: SyntaxWarning: invalid escape sequence '\ '
#   ax.set_title(f'{tex_kernel}\n' r'$r = ' f'{rad}\ m$', fontsize=15, pad=10)
# ...

# %%
plot_scalability_lines(SUBSET_DATA, "Mar18_test", 256, 16)
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\subset\Mar18_test
# ..\out_tfg_reorders_v3\subset\Mar18_test
# Loading results file: ..\out_tfg_reorders_v3\subset\Mar18_test\Mar18_test-2026-06-07-15_29_47.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Mar18_test\Mar18_test-2026-06-07-15_58_47.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Mar18_test\Mar18_test-2026-06-07-15_27_11.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Mar18_test\Mar18_test-2026-06-07-16_01_58.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Mar18_test\Mar18_test-2026-06-07-15_46_06.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Mar18_test\Mar18_test-2026-06-07-15_52_17.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Mar18_test\Mar18_test-2026-06-07-15_49_08.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\Mar18_test\Mar18_test-2026-06-07-15_24_38.csv
# ...

# %%
plot_scalability_lines(SUBSET_DATA, PNOA, 512, 64)
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\subset\PNOA_2024_PNR_489-4672_NPC01
# ..\out_tfg_reorders_v3\subset\PNOA_2024_PNR_489-4672_NPC01
# Loading results file: ..\out_tfg_reorders_v3\subset\PNOA_2024_PNR_489-4672_NPC01\PNOA_2024_PNR_489-4672_NPC01-2026-06-07-14_42_36.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\PNOA_2024_PNR_489-4672_NPC01\PNOA_2024_PNR_489-4672_NPC01-2026-06-07-14_48_52.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\PNOA_2024_PNR_489-4672_NPC01\PNOA_2024_PNR_489-4672_NPC01-2026-06-07-14_41_59.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\PNOA_2024_PNR_489-4672_NPC01\PNOA_2024_PNR_489-4672_NPC01-2026-06-07-14_47_22.csv
# Loading results file: ..\out_tfg_reorders_v3\subset\PNOA_2024_PNR_489-4672_NPC01\PNOA_2024_PNR_489-4672_NPC01-2026-06-07-14_45_55.csv
# ...

# %% [markdown]
# # FULL SEARCHES

# %% [markdown]
# ### Tiempos de ejecución según el radio para cada búsqueda completa en cada nube
# Para búsquedas completas se usaron solo un subconjunto de nubes y una combinación de hiperparámetros.

# %%
plot_scalability_lines(FULL_DATA, "5085_54320")
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\full\5085_54320
# ..\out_tfg_reorders_v3\full\5085_54320
# Loading results file: ..\out_tfg_reorders_v3\full\5085_54320\5085_54320-2026-06-08-13_27_59.csv

# %%
plot_scalability_lines(FULL_DATA, PNOA)
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\full\PNOA_2024_PNR_489-4672_NPC01
# ..\out_tfg_reorders_v3\full\PNOA_2024_PNR_489-4672_NPC01
# Loading results file: ..\out_tfg_reorders_v3\full\PNOA_2024_PNR_489-4672_NPC01\PNOA_2024_PNR_489-4672_NPC01-2026-06-08-13_39_38.csv

# %%
plot_scalability_lines(FULL_DATA, "Paris_Luxembourg_6")
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\full\Paris_Luxembourg_6
# ..\out_tfg_reorders_v3\full\Paris_Luxembourg_6
# Loading results file: ..\out_tfg_reorders_v3\full\Paris_Luxembourg_6\Paris_Luxembourg_6-2026-06-08-15_09_53.csv

# %%
plot_scalability_lines(FULL_DATA, "Mar18_train")
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\full\Mar18_train
# ..\out_tfg_reorders_v3\full\Mar18_train
# Loading results file: ..\out_tfg_reorders_v3\full\Mar18_train\Mar18_train-2026-06-08-13_48_39.csv

# %%
plot_scalability_lines(FULL_DATA, "bildstein_station1_xyz_intensity_rgb")
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\full\bildstein_station1_xyz_intensity_rgb
# ..\out_tfg_reorders_v3\full\bildstein_station1_xyz_intensity_rgb
# Loading results file: ..\out_tfg_reorders_v3\full\bildstein_station1_xyz_intensity_rgb\bildstein_station1_xyz_intensity_rgb-2026-06-08-16_48_29.csv

# %% [markdown]
# ## Resultados de escalabilidad de paralelización

# %% [markdown]
# Resultados sobre subsets (10.000 búsquedas aleatorias)

# %%
figs = plot_octree_parallelization_heatmap(PARALLEL_SUBSET_DATA, "Paris_Luxembourg_6", mode_filter="all", allFiles=True)
# Out:
# Failed to read module file '\\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\plots_manu\plots.py' for module 'plots': UnicodeDecodeError
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Roaming\Python\Python313\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 556, in maybe_reload_module
#     new_source_code = f.read()
#   File "c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 1296: character maps to <undefined>
# \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\plots_manu\plots.py:839: SyntaxWarning: invalid escape sequence '\ '
#   ax.set_title(f'{tex_kernel}\n' r'$r = ' f'{rad}\ m$', fontsize=15, pad=10)
# ...

# %%
figs = plot_octree_parallelization_heatmap(PARALLEL_SUBSET_DATA, "bildstein_station1_xyz_intensity_rgb", mode_filter="all", allFiles=True)
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\parallel_subset\bildstein_station1_xyz_intensity_rgb
# ..\out_tfg_reorders_v3\parallel_subset\bildstein_station1_xyz_intensity_rgb
# Loading results file: ..\out_tfg_reorders_v3\parallel_subset\bildstein_station1_xyz_intensity_rgb\bildstein_station1_xyz_intensity_rgb-2026-06-10-20_46_00.csv

# %%
figs = plot_octree_parallelization_heatmap(PARALLEL_SUBSET_DATA, "5085_54320", mode_filter="all", allFiles=True)
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\parallel_subset\5085_54320
# ..\out_tfg_reorders_v3\parallel_subset\5085_54320
# Loading results file: ..\out_tfg_reorders_v3\parallel_subset\5085_54320\5085_54320-2026-06-10-20_41_57.csv

# %%
figs = plot_octree_parallelization_heatmap(PARALLEL_SUBSET_DATA, "Mar18_train", mode_filter="all", allFiles=True)
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\parallel_subset\Mar18_train
# ..\out_tfg_reorders_v3\parallel_subset\Mar18_train
# Loading results file: ..\out_tfg_reorders_v3\parallel_subset\Mar18_train\Mar18_train-2026-06-10-20_42_28.csv

# %%
figs = plot_octree_parallelization_heatmap(PARALLEL_SUBSET_DATA, "PNOA_2024_PNR_489-4672_NPC01", mode_filter="all", allFiles=True)
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\parallel_subset\PNOA_2024_PNR_489-4672_NPC01
# ..\out_tfg_reorders_v3\parallel_subset\PNOA_2024_PNR_489-4672_NPC01
# Loading results file: ..\out_tfg_reorders_v3\parallel_subset\PNOA_2024_PNR_489-4672_NPC01\PNOA_2024_PNR_489-4672_NPC01-2026-06-10-20_42_13.csv

# %% [markdown]
# Resultados sobre coberturas completas

# %%
figs = plot_octree_parallelization_heatmap(PARALLEL_FULL_DATA, "Lille_0", mode_filter="all", allFiles=True)
# Out:
# Buscando archivos en: \\wsl.localhost\Ubuntu\home\manu\proyecto_tfg\octrees-coordenadas-polares-v2\out_tfg_reorders_v3\parallel_full\Lille_0
# ..\out_tfg_reorders_v3\parallel_full\Lille_0
# Loading results file: ..\out_tfg_reorders_v3\parallel_full\Lille_0\Lille_0-2026-06-10-20_46_35.csv
