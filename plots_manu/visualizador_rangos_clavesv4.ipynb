# %% [markdown]
# ### Porcentaje de puntos evaluados con reordenaciones EJECUCIÓN VERSIÓN 2

# %%
from utils import *
from plots import *
from constants import *
from pathlib import Path
import os


# %load_ext autoreload
# %autoreload 2

RANGES_PATH = os.path.join("..", "outv4-ranges")
LEAVES_PATH = os.path.join("..", "outv4-leaves")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cesga = True

# %%
if cesga:
    for log in Path(RANGES_PATH).glob('*.log'):
        plot_pruning_points(log, save=False)
else:
    plot_pruning_points('../prueba/Lille_0/ranges/Lille_0_20260512_142130.log', save=False)

# %% [markdown]
# ### Distribuciones de las podas

# %%
if cesga:
    for log in Path(RANGES_PATH).glob('*.log'):
        plot_pruning_distribution(log, save=False)
else:
    plot_pruning_distribution('../prueba/Lille_0/ranges/Lille_0_20260512_142130.log', save=False)

# %%
if cesga:
    for log in Path(RANGES_PATH).glob('*.log'):
        plot_density_analysis(log)
else:
    plot_density_analysis('../prueba/Lille_0/ranges/Lille_0_20260512_142130.log')

# %%
if cesga:
    for log in Path(RANGES_PATH).glob('*.log'):
        plot_key_distribution(log)
else:
    plot_key_distribution('../prueba/Lille_0/ranges/Lille_0_20260512_142130.log')

# %% [markdown]
# ## Visualización tiempo empleado en selector de rangos vs evaluación puntos

# %%
if cesga:
    for log in Path(LEAVES_PATH).glob('*.csv'):
        if 'sg' in log.name:
            analyze_speedup_and_timing(log, save=False)
