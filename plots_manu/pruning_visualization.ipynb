# %%
import os
import seaborn as sns
from utils import *
from plots import *
from constants import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
plot_octree_pruning_polar()

# %%
plot_octree_pruning_cartesian_x()
